# %%
import requests
from bs4 import BeautifulSoup

# %%
# url1="https://quotes.toscrape.com/page/1/"
# url2="https://quotes.toscrape.com/page/2/"
# url3="https://quotes.toscrape.com/page/3/"
# url4="https://quotes.toscrape.com/page/4/"
# url5="https://quotes.toscrape.com/page/5/"
# url6="https://quotes.toscrape.com/page/6/"
# url7="https://quotes.toscrape.com/page/7/"
# url8="https://quotes.toscrape.com/page/8/"
# url9="https://quotes.toscrape.com/page/9/"
# url10="https://quotes.toscrape.com/page/10/"

URL=[]
for i in range(1,11):
    f"url{i}=https://quotes.toscrape.com/page/{i}/"
    URL.append(f"url{i}")


RES=[]
for i in range(1,11):
    f"res{i}=requests.get(url{i})"
    RES.append(f"res{i}")

# res=requests.get(URL[])
# res2=requests.get(url2)
# res3=requests.get(url3)
# res4=requests.get(url4)
# res5=requests.get(url5)
# res6=requests.get(url6)
# res7=requests.get(url7)
# res8=requests.get(url8)
# res9=requests.get(url9)
# res10=requests.get(url10)

# for i in range(1,11):
#     f"res{i}=requests.get(url{i})"

# for i in range(1,11):
#     f"res{i}"


res1
res2
res3
res4
res5
res6
res7
res8
res9
res10
# Out:
# <Response [200]>

# %%
with open("assignment/data1.html","w",encoding="utf8") as f:
    f.write(res1.text)
with open("assignment/data2.html","w",encoding="utf8") as f:
    f.write(res2.text)
with open("assignment/data3.html","w",encoding="utf8") as f:
    f.write(res3.text)  
with open("assignment/data4.html","w",encoding="utf8") as f:
    f.write(res4.text)
with open("assignment/data5.html","w",encoding="utf8") as f:
    f.write(res5.text)
with open("assignment/data6.html","w",encoding="utf8") as f:
    f.write(res6.text)
with open("assignment/data7.html","w",encoding="utf8") as f:
    f.write(res7.text)
with open("assignment/data8.html","w",encoding="utf8") as f:
    f.write(res8.text)
with open("assignment/data9.html","w",encoding="utf8") as f:
    f.write(res9.text)
with open("assignment/data10.html","w",encoding="utf8") as f:
    f.write(res10.text)

for i in range(1,11):
    f" with open(assignment/data{i}.html","w",encoding='utf8') as f:
        (f.write(res{i}.text))

# %%
with open("scraped_data/data11.html","r",encoding="utf8") as f:
     html_content1=f.read()
with open("scraped_data/data12.html","r",encoding="utf8") as f:
     html_content2=f.read()
with open("scraped_data/data13.html","r",encoding="utf8") as f:
     html_content3=f.read()
with open("scraped_data/data14.html","r",encoding="utf8") as f:
     html_content4=f.read()
with open("scraped_data/data15.html","r",encoding="utf8") as f:
     html_content5=f.read()
with open("scraped_data/data16.html","r",encoding="utf8") as f:
     html_content6=f.read()
with open("scraped_data/data17.html","r",encoding="utf8") as f:
     html_content7=f.read()
with open("scraped_data/data18.html","r",encoding="utf8") as f:
     html_content8=f.read()
with open("scraped_data/data19.html","r",encoding="utf8") as f:
     html_content9=f.read()
with open("scraped_data/data10.html","r",encoding="utf8") as f:
     html_content10=f.read()
    

all_html = (
    html_content1 + html_content2 + html_content3 + html_content4 +
    html_content5 + html_content6 + html_content7 + html_content8 +
    html_content9 + html_content10
)

soup = BeautifulSoup(all_html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
all_quotes=soup.select("div.quote")
# life_quote=[]

all_tag =q.select(".tag-item")
print(all_tag)
# for q in all_quotes:
#     all_tags=[]

#     for tag in q.select(".tag"):
#         all_tags.append(tag.get_text())

     # if "life" in all_tags:
     #     text=q.select_one("span.text").get_text()
     #     auther=q.select_one("small.auther").get_text()

     #     life_quote.append(text,auther)

print(all_tags)
# print(life_quote)
# Out:
# []
# ['humor', 'obvious', 'simile']

# %%
all_quotes
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# ...
